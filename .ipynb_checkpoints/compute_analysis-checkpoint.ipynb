# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import os
import pandas as pd
import plotly.express as px
import plotly.io as pio

# notebook renderer wasn't working for me. unfortunately pngs aren't interactive
pio.renderers.default = 'png'

from data import *
from plotting import *
from regression import *
from utils import *

# %%
results_dir = 'results/updated-schema/'
os.makedirs(results_dir, exist_ok=True)

# %%
# Load data
pcd_df = load_pcd_df()

# %%
pcd_df
# Out:
#                       System                                       Domain  \
# 0           Gemini 1.0 Ultra                   Multimodal,Language,Vision
# 1                      GPT-4  Multimodal,Language,Vision,Image generation
# 2              Mistral Large                                     Language
# 3            Nemotron-4 340B                                     Language
# 4     MegaScale (Production)                                     Language
# ...                      ...                                          ...
# 1590               Audioseal                                 Audio,Speech
# 1591            GLM-4 (0520)                                     Language
# 1592         GLM-4 All Tools         Language,Multimodal,Image generation
# 1593        Multilingual DNN                                       Speech
# 1594                  DeViSE                                       Vision
#
#                                                    Task Publication date  \
# 0     Language modelling,Visual question answering,C...       2023-12-06
# 1                                    Language modelling       2023-03-15
# 2                                                  Chat       2024-02-26
# 3                    Language modelling/generation,Chat       2024-06-14
# 4                         Language modelling/generation       2024-02-23
# ...                                                 ...              ...
# 1590              Audio classification,Audio generation       2024-06-06
# 1591  Language modelling/generation,Question answeri...       2024-06-18
# 1592  Language modelling/generation,Question answeri...       2024-01-17
# 1593                                 Speech recognition       2013-05-26
# 1594                                 Semantic embedding       2013-12-05
#
#                                     Accessibility notes  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Permissive commercial license: https://develop...
# 4     Code for MegaScale (also called veScale) train...
# ...                                                 ...
# 1590  The code in this repository is released under ...
# 1591              the GLM-4 API at\nhttps://bigmodel.cn
# 1592  GLM-4 All Tools is accessible via the website ...
# 1593                                                NaN
# 1594                                                NaN
#
#          Model accessibility Dataset accessibility Code accessibility  \
# 0     Hosted access (no API)                   NaN         Unreleased
# 1                 API access                   NaN         Unreleased
# 2                 API access                   NaN         Unreleased
# 3                Open source                   NaN                NaN
# 4                 Unreleased                   NaN         Unreleased
# ...                      ...                   ...                ...
# 1590                     NaN                   NaN        Open source
# 1591              API access                   NaN                NaN
# 1592  Hosted access (no API)                   NaN                NaN
# 1593                     NaN                   NaN                NaN
# 1594                     NaN                   NaN                NaN
#
#                                                    Link  \
# 0     https://storage.googleapis.com/deepmind-media/...
# 1                      https://arxiv.org/abs/2303.08774
# 2                https://mistral.ai/news/mistral-large/
# 3     https://blogs.nvidia.com/blog/nemotron-4-synth...
# 4                      https://arxiv.org/abs/2402.15627
# ...                                                 ...
# 1590                   https://arxiv.org/abs/2401.17264
# 1591                   https://arxiv.org/abs/2406.12793
# 1592                   https://arxiv.org/abs/2406.12793
# 1593  https://www.semanticscholar.org/paper/Multilin...
# 1594  https://www.semanticscholar.org/paper/DeViSE%3...
#
#                      Organization  ...  Organization categorization  \
# 0                 Google DeepMind  ...                     Industry
# 1                          OpenAI  ...                     Industry
# 2                      Mistral AI  ...                     Industry
# 3                          NVIDIA  ...                     Industry
# 4     ByteDance,Peking University  ...            Industry,Academia
# ...                           ...  ...                          ...
# 1590         Facebook AI Research  ...                     Industry
# 1591                     Zhipu AI  ...                     Industry
# 1592                     Zhipu AI  ...                     Industry
# 1593                       Google  ...                     Industry
# 1594                       Google  ...                     Industry
#
#      Foundation model Training compute lower bound  \
# 0                 NaN                          NaN
# 1             checked                          NaN
# 2                 NaN                          NaN
# 3                 NaN                          NaN
# 4                 NaN                          NaN
# ...               ...                          ...
# 1590              NaN                          NaN
# 1591              NaN                          NaN
# 1592              NaN                          NaN
# 1593              NaN                          NaN
# 1594              NaN                          NaN
#
#      Training compute upper bound Training chip-hours  \
# 0                             NaN         132000000.0
# 1                             NaN          57000000.0
# 2                             NaN                 NaN
# 3                             NaN                 NaN
# 4                             NaN                 NaN
# ...                           ...                 ...
# 1590                          NaN                 NaN
# 1591                          NaN                 NaN
# 1592                          NaN                 NaN
# 1593                          NaN                 NaN
# 1594                          NaN                 NaN
#
#      Organization categorization (from Organization) Possibly over 1e23 FLOP  \
# 0                                           Industry                     NaN
# 1                                           Industry                     NaN
# 2                                           Industry                     NaN
# 3                                           Industry                     NaN
# 4                                  Industry,Academia                     NaN
# ...                                              ...                     ...
# 1590                                        Industry                     NaN
# 1591                                        Industry                 checked
# 1592                                        Industry                 checked
# 1593                                        Industry                     NaN
# 1594                                        Industry                     NaN
#
#      Training compute cost (2023 USD)   Training dataset size  Sparsity
# 0                        $29827341.92        Gemini 1.0 Ultra       NaN
# 1                        $40586592.58                   GPT-4     GPT-4
# 2                                 NaN           Mistral Large       NaN
# 3                                 NaN         Nemotron-4 340B       NaN
# 4                                 NaN  MegaScale (Production)       NaN
# ...                               ...                     ...       ...
# 1590                              NaN                     NaN       NaN
# 1591                              NaN                   GLM-4       NaN
# 1592                              NaN                   GLM-4       NaN
# 1593                              NaN                     NaN       NaN
# 1594                              NaN                     NaN       NaN
#
# [1595 rows x 61 columns]

# %%
pcd_df.loc[pcd_df['System'] == 'Megatron-BERT']['Model accessibility']
# Out:
# 139    Unreleased
# Name: Model accessibility, dtype: object

# %%
access_df = pcd_df.dropna(subset=['Publication date', 'Training compute (FLOP)', 'Model accessibility'])
len(access_df)
# Out:
# 534

# %%
access_df['Model accessibility'].unique()
# Out:
# array(['Hosted access (no API)', 'API access', 'Open source',
#        'Unreleased', 'Open access (restricted use)',
#        'Open access (non-commercial)'], dtype=object)

# %%
for cat in access_df['Model accessibility'].unique():
    print(cat, len(access_df.loc[access_df['Model accessibility'] == cat]))
# Out:
# Hosted access (no API) 10
# API access 26
# Open source 201
# Unreleased 199
# Open access (restricted use) 48
# Open access (non-commercial) 50

# %%
open_access_categories = ['Open source', 'Open access (restricted use)', 'Open access (non-commercial)']
closed_access_categories = ['API access', 'Hosted access (no API)', 'Unreleased']

# %%
open_access_df = access_df.loc[access_df['Model accessibility'].isin(open_access_categories)]
len(open_access_df)
# Out:
# 299

# %%
closed_access_df = access_df.loc[access_df['Model accessibility'].isin(closed_access_categories)]
len(closed_access_df)
# Out:
# 235

# %%
# Add column with binary access label
access_df['Model open/closed'] = access_df['Model accessibility'].apply(
    lambda x: 'Open' if x in open_access_categories else 'Closed'
)
# Out:
# /var/folders/06/5htx0qw164j099bw2q7jk4gm0000gn/T/ipykernel_72057/148813227.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
access_df
# Out:
#                      System                                       Domain  \
# 0          Gemini 1.0 Ultra                   Multimodal,Language,Vision
# 1                     GPT-4  Multimodal,Language,Vision,Image generation
# 2             Mistral Large                                     Language
# 3           Nemotron-4 340B                                     Language
# 4    MegaScale (Production)                                     Language
# ..                      ...                                          ...
# 649           AFP+FPI (PTB)                                     Language
# 650            bRSM + cache                                     Language
# 652                life2vec                                     Medicine
# 663                 SPIDER2                                      Biology
# 702      Credibilty Network                                       Vision
#
#                                                   Task Publication date  \
# 0    Language modelling,Visual question answering,C...       2023-12-06
# 1                                   Language modelling       2023-03-15
# 2                                                 Chat       2024-02-26
# 3                   Language modelling/generation,Chat       2024-06-14
# 4                        Language modelling/generation       2024-02-23
# ..                                                 ...              ...
# 649                                                NaN       2021-06-04
# 650                                                NaN       2019-12-02
# 652                               Mortality prediction       2023-06-05
# 663                Protein folding prediction,Proteins       2016-10-28
# 702         Character recognition,Image classification       1999-07-01
#
#                                    Accessibility notes  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Permissive commercial license: https://develop...
# 4    Code for MegaScale (also called veScale) train...
# ..                                                 ...
# 649                                                NaN
# 650  GNU (copyleft) license for code: https://githu...
# 652        License: Not for public use or distribution
# 663  some kind of download, unclear license\n\nhttp...
# 702                                                NaN
#
#               Model accessibility Dataset accessibility Code accessibility  \
# 0          Hosted access (no API)                   NaN         Unreleased
# 1                      API access                   NaN         Unreleased
# 2                      API access                   NaN         Unreleased
# 3                     Open source                   NaN                NaN
# 4                      Unreleased                   NaN         Unreleased
# ..                            ...                   ...                ...
# 649                    Unreleased                   NaN         Unreleased
# 650                    Unreleased                   NaN        Open source
# 652                    Unreleased                   NaN                NaN
# 663  Open access (non-commercial)                   NaN                NaN
# 702                    Unreleased                   NaN         Unreleased
#
#                                                   Link  \
# 0    https://storage.googleapis.com/deepmind-media/...
# 1                     https://arxiv.org/abs/2303.08774
# 2               https://mistral.ai/news/mistral-large/
# 3    https://blogs.nvidia.com/blog/nemotron-4-synth...
# 4                     https://arxiv.org/abs/2402.15627
# ..                                                 ...
# 649                   https://arxiv.org/abs/2106.02417
# 650                   https://arxiv.org/abs/1912.01116
# 652                   https://arxiv.org/abs/2306.03009
# 663  https://link.springer.com/protocol/10.1007/978...
# 702  https://proceedings.neurips.cc/paper_files/pap...
#
#                                           Organization  ...  Foundation model  \
# 0                                      Google DeepMind  ...               NaN
# 1                                               OpenAI  ...           checked
# 2                                           Mistral AI  ...               NaN
# 3                                               NVIDIA  ...               NaN
# 4                          ByteDance,Peking University  ...               NaN
# ..                                                 ...  ...               ...
# 649                            University of Sheffield  ...               NaN
# 650                              Numenta,Incubator 491  ...               NaN
# 652  Technical University of Denmark,University of ...  ...               NaN
# 663  Griffith University,University of Iowa,Dezhou ...  ...               NaN
# 702  University College London (UCL),University of ...  ...               NaN
#
#     Training compute lower bound Training compute upper bound  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# ..                           ...                          ...
# 649                          NaN                          NaN
# 650                          NaN                          NaN
# 652                          NaN                          NaN
# 663                          NaN                          NaN
# 702                          NaN                          NaN
#
#     Training chip-hours Organization categorization (from Organization)  \
# 0           132000000.0                                        Industry
# 1            57000000.0                                        Industry
# 2                   NaN                                        Industry
# 3                   NaN                                        Industry
# 4                   NaN                               Industry,Academia
# ..                  ...                                             ...
# 649                 NaN                                        Academia
# 650                 NaN                                        Industry
# 652                 NaN                               Academia,Academia
# 663                 NaN                      Academia,Academia,Academia
# 702                 NaN                               Academia,Academia
#
#     Possibly over 1e23 FLOP Training compute cost (2023 USD)  \
# 0                       NaN                     $29827341.92
# 1                       NaN                     $40586592.58
# 2                       NaN                              NaN
# 3                       NaN                              NaN
# 4                       NaN                              NaN
# ..                      ...                              ...
# 649                     NaN                              NaN
# 650                     NaN                              NaN
# 652                     NaN                              NaN
# 663                     NaN                              NaN
# 702                     NaN                              NaN
#
#       Training dataset size Sparsity  Model open/closed
# 0          Gemini 1.0 Ultra      NaN             Closed
# 1                     GPT-4    GPT-4             Closed
# 2             Mistral Large      NaN             Closed
# 3           Nemotron-4 340B      NaN               Open
# 4    MegaScale (Production)      NaN             Closed
# ..                      ...      ...                ...
# 649           AFP+FPI (PTB)      NaN             Closed
# 650            bRSM + cache      NaN             Closed
# 652                life2vec      NaN             Closed
# 663                 SPIDER2      NaN               Open
# 702      Credibilty Network      NaN             Closed
#
# [534 rows x 62 columns]

# %% [markdown]
# ## Compute percentile filtering (skipped for now in regression/viz code)

# %%
outlier_window_size = 2  # years
start_large_scale_era = '2015-09-01'

# %%
pcd_df['Publication date'] = pd.to_datetime(pcd_df['Publication date'])
pcd_df.sort_values('Publication date', inplace=True)
pcd_df.dropna(subset=['Publication date', 'Notability criteria', 'Training compute (FLOP)'], inplace=True)

# %%
systems_by_percentile = {}
percentile_interval = 5
for percentile in range(95, -5, -percentile_interval):
  print(percentile)
  percentile_compute_low = np.zeros(len(pcd_df))
  percentile_compute_high = np.zeros(len(pcd_df))
  # Iterate through each row and calculate the 2-year moving average for each date
  for i, (index, row) in enumerate(pcd_df.iterrows()):
    # Define the 2-year window
    start_date = row['Publication date'] - pd.DateOffset(years=outlier_window_size/2)
    end_date = row['Publication date'] + pd.DateOffset(years=outlier_window_size/2)

    # Filter the DataFrame for this window
    window_df = pcd_df[(pcd_df['Publication date'] >= start_date) & (pcd_df['Publication date'] <= end_date)]

    percentile_compute_low[i] = np.percentile(window_df['Training compute (FLOP)'], percentile)
    percentile_compute_high[i] = np.percentile(window_df['Training compute (FLOP)'], percentile + percentile_interval)

  systems_flag = pcd_df['Training compute (FLOP)'] > np.array(percentile_compute_low)
  extra_systems_flag = pcd_df['Training compute (FLOP)'] <= np.array(percentile_compute_high)

  # raise Exception("Edit the following line if you want to consider models released after 2023-12-31.")
  extra_systems = pcd_df['System'][systems_flag & extra_systems_flag & (pcd_df['Publication date'] > pd.to_datetime('2015-09-30'))].values

  systems_by_percentile[percentile] = list(extra_systems)
# Out:
# 95
# 90
# 85
# 80
# 75
# 70
# 65
# 60
# 55
# 50
# 45
# 40
# 35
# 30
# 25
# 20
# 15
# 10
# 5
# 0

# %%
compute_percentile_threshold = 50
selected_systems = []
for percentile in range(compute_percentile_threshold, 100, 5):
    selected_systems.extend(systems_by_percentile[percentile])
selected_systems
# Out:
# ['BIDAF',
#  'Transformer',
#  'GPT',
#  'ProxylessNAS',
#  'GBERT-Large',
#  'wave2vec 2.0 LARGE',
#  'AlphaFold 2',
#  'DeBERTa',
#  'HuBERT',
#  'PLATO-XL',
#  'Imagen',
#  'ProGen2-xlarge',
#  'NLLB',
#  'ESM2-3B',
#  'LLaMA-7B',
#  'LLaMA-13B',
#  'ChatGLM3-6B',
#  'Llama Guard',
#  'DeepStack',
#  'LSTM (Hebbian, Cache, MbPA)',
#  'SciBERT',
#  'DD-PPO',
#  'ViT-Huge/14',
#  'MSA Transformer',
#  'M6-T',
#  'ADM',
#  'XGLM',
#  'RETRO-7B',
#  'Flan-T5 11B',
#  'WizardCoder-15.5B',
#  'Llama 2-13B',
#  'Llama 2-7B',
#  'FinGPT-13B',
#  'Nemotron-3-8B',
#  'MegaScale (175B)',
#  'ResNet-200',
#  'QT-Opt',
#  'Population-based DRL',
#  'Mesh-TensorFlow Transformer 2.9B (translation)',
#  'Megatron-LM (355M)',
#  'T5-3B',
#  'CamemBERT',
#  'Noisy Student (L2)',
#  'Once for All',
#  'ERNIE 3.0',
#  'Student of Games',
#  'XGLM-7.5B',
#  'PaLI',
#  'Taiyi-Stable Diffusion',
#  'StarCoder',
#  'Skywork-13B',
#  'MM1-30B',
#  'ResNet-152 (ImageNet)',
#  'ConvS2S (ensemble of 8 models)',
#  'PNASNet-5',
#  'YOLOv3',
#  'Transformer (Adaptive Input Embeddings) WT103',
#  'BERT-Large-CAS (PTB+WT2+WT103)',
#  'Conformer + Wav2vec 2.0 + Noisy Student',
#  'CLIP (ViT L/14@336px)',
#  'CogView',
#  'ALIGN',
#  'BASIC-L',
#  'Stable Diffusion (LDM-KL-8-G)',
#  'CoCa',
#  'ESM2-15B',
#  'Falcon-40B',
#  'BloombergGPT',
#  'FunSearch',
#  'Llama 3-8B',
#  'DeepSpeech2 (English)',
#  'PolyNet',
#  'MoE',
#  'Big Transformer for Back-Translation',
#  'Mesh-TensorFlow Transformer 4.9B (language modelling)',
#  'MnasNet-A1 + SSDLite',
#  'MnasNet-A3',
#  'ALBERT-xxlarge',
#  'ELECTRA',
#  'iGPT-L',
#  'PLUG',
#  'ProtT5-XXL-BFD',
#  'ProtBERT-BFD',
#  'CoAtNet',
#  'FLAN 137B',
#  'Florence',
#  'AlexaTM 20B',
#  'Llama 2-34B',
#  'DeepSeek-Coder-V2-236B',
#  'ESM3 (98B)',
#  'Xception',
#  'Libratus',
#  'BERT-Large',
#  'RoBERTa Large',
#  'ContextNet + Noisy Student',
#  'ProtT5-XXL',
#  'GPT-NeoX-20B',
#  'UL2',
#  'Galactica',
#  'ViT-22B',
#  'PanGu-Σ',
#  'xTrimoPGLM -100B',
#  'Yi-34B',
#  'MegaScale (530B)',
#  'OpenAI TI7 DOTA 1v1',
#  'IMPALA',
#  'BigGAN-deep 512x512',
#  'GPT-2 (1.5B)',
#  'iGPT-XL',
#  'DALL-E',
#  'Meta Pseudo Labels',
#  'ByT5-XXL',
#  'GOAT',
#  'HyperCLOVA 82B',
#  'AlphaCode',
#  'ST-MoE',
#  'Flamingo',
#  'GLM-130B',
#  'BlenderBot 3',
#  'LLaMA-65B',
#  'Llama 2-70B',
#  'Qwen-72B',
#  'AlphaGo Fan',
#  'AlphaGo Lee',
#  'JFT',
#  'AmoebaNet-A (F=448)',
#  'XLNet',
#  'Megatron-LM (8.3B)',
#  'T5-11B',
#  'OpenAI Five Rerun',
#  'Turing-NLG',
#  'Yuan 1.0',
#  'GLaM',
#  'LaMDA',
#  'OPT-175B',
#  'Parti',
#  'BLOOM-176B',
#  'Falcon-180B',
#  'Grok-1',
#  'Inflection-2.5',
#  'Llama 3-70B',
#  'NASv3 (CIFAR-10)',
#  'FTW',
#  'Megatron-BERT',
#  'AlphaStar',
#  'OpenAI Five',
#  'mT5-XXL',
#  'Switch',
#  'Gopher (280B)',
#  'ERNIE 3.0 Titan',
#  'Chinchilla',
#  'Flan-PaLM 540B',
#  'U-PaLM (540B)',
#  'GPT-3.5 (text-davinci-003)',
#  'PaLM 2',
#  'Claude 2',
#  'Inflection-2',
#  'MegaScale (Production)',
#  'GNMT',
#  'AlphaGo Master',
#  'AlphaGo Zero',
#  'AlphaZero',
#  'ResNeXt-101 32x48d',
#  'Meena',
#  'GPT-3 175B (davinci)',
#  'GShard (dense)',
#  'Megatron-Turing NLG 530B',
#  'PaLM (540B)',
#  'Minerva (540B)',
#  'GPT-4',
#  'Gemini 1.0 Ultra',
#  'Mistral Large',
#  'Nemotron-4 340B']

# %% [markdown]
# # Top-n frontier filtering

# %%
access_df['Publication date (float)'] = datetime_to_float_year(
    pd.to_datetime(access_df['Publication date'])
)
# Out:
# /var/folders/06/5htx0qw164j099bw2q7jk4gm0000gn/T/ipykernel_72057/3991044387.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
n = 10

access_df[f'top_{n}_at_release'] = False

for row, model in access_df.iterrows():
    # Filter for models released as of the model release, with the same open/closed status
    date_df = access_df[(access_df['Publication date (float)'] <= model['Publication date (float)']) 
        & (access_df['Model open/closed'] == model['Model open/closed'])]
    # Get the top n models (with the same open/closed status) by compute
    top_n_models = date_df.nlargest(n, 'Training compute (FLOP)')
    # Mark these models in the original dataframe
    access_df.loc[top_n_models.index, f'top_{n}_at_release'] = True
# Out:
# /var/folders/06/5htx0qw164j099bw2q7jk4gm0000gn/T/ipykernel_72057/1055558449.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
access_df[(access_df['top_10_at_release'] == True) & (access_df['Model open/closed'] == 'Open')]
# Out:
#                       System    Domain  \
# 3            Nemotron-4 340B  Language
# 8                Llama 3-70B  Language
# 11               Falcon-180B  Language
# 12                    Grok-1  Language
# 14                      DBRX  Language
# ..                       ...       ...
# 564  Big-Little Net (speech)    Speech
# 573                  ULM-FiT  Language
# 574           Big-Little Net    Vision
# 589                   DNCON2   Biology
# 663                  SPIDER2   Biology
#
#                                                   Task Publication date  \
# 3                   Language modelling/generation,Chat       2024-06-14
# 8    Chat,Language modelling/generation,Code genera...       2024-04-18
# 11                                  Language modelling       2023-09-06
# 12                             Language modelling,Chat       2023-11-04
# 14                                Chat,Code generation       2024-03-27
# ..                                                 ...              ...
# 564                                 Speech recognition       2018-07-10
# 573                                Text classification       2018-01-18
# 574                               Image classification       2018-07-10
# 589                Proteins,Protein folding prediction       2018-05-01
# 663                Protein folding prediction,Proteins       2016-10-28
#
#                                    Accessibility notes  \
# 3    Permissive commercial license: https://develop...
# 8    https://github.com/meta-llama/llama3/blob/main...
# 11   "Falcon 180b can be commercially used but unde...
# 12                                          apache 2.0
# 14   license: https://www.databricks.com/legal/open...
# ..                                                 ...
# 564  apache for code/weights: \nhttps://github.com/...
# 573   https://nlp.fast.ai/category/classification.html
# 574  Apache 2 license\nhttps://github.com/IBM/BigLi...
# 589  license: https://github.com/multicom-toolbox/D...
# 663  some kind of download, unclear license\n\nhttp...
#
#               Model accessibility Dataset accessibility  \
# 3                     Open source                   NaN
# 8    Open access (restricted use)                   NaN
# 11   Open access (restricted use)                   NaN
# 12                    Open source            Unreleased
# 14   Open access (restricted use)            Unreleased
# ..                            ...                   ...
# 564                   Open source                   NaN
# 573                   Open source                   NaN
# 574                   Open source                   NaN
# 589                   Open source           Open source
# 663  Open access (non-commercial)                   NaN
#
#                Code accessibility  \
# 3                             NaN
# 8    Open access (restricted use)
# 11                     Unreleased
# 12                     Unreleased
# 14                     Unreleased
# ..                            ...
# 564                   Open source
# 573                   Open source
# 574                   Open source
# 589                   Open source
# 663                           NaN
#
#                                                   Link  \
# 3    https://blogs.nvidia.com/blog/nemotron-4-synth...
# 8               https://ai.meta.com/blog/meta-llama-3/
# 11   https://falconllm.tii.ae/falcon-180b.html; htt...
# 12   https://x.ai/model-card/, https://x.ai/blog/gr...
# 14   https://www.databricks.com/blog/introducing-db...
# ..                                                 ...
# 564                   https://arxiv.org/abs/1807.03848
# 573                   https://arxiv.org/abs/1801.06146
# 574                   https://arxiv.org/abs/1807.03848
# 589  https://academic.oup.com/bioinformatics/articl...
# 663  https://link.springer.com/protocol/10.1007/978...
#
#                                           Organization  ...  \
# 3                                               NVIDIA  ...
# 8                                              Meta AI  ...
# 11                     Technology Innovation Institute  ...
# 12                                                 xAI  ...
# 14                                          Databricks  ...
# ..                                                 ...  ...
# 564                                                IBM  ...
# 573  University of San Francisco,Insight Centre NUI...  ...
# 574                                                IBM  ...
# 589                             University of Missouri  ...
# 663  Griffith University,University of Iowa,Dezhou ...  ...
#
#      Training compute upper bound Training chip-hours  \
# 3                             NaN                 NaN
# 8                             NaN           6400000.0
# 11                            NaN          17694720.0
# 12                            7.0                 NaN
# 14                            NaN                 NaN
# ..                            ...                 ...
# 564                           NaN                 NaN
# 573                           NaN                 NaN
# 574                           NaN                 NaN
# 589                           NaN                 NaN
# 663                           NaN                 NaN
#
#     Organization categorization (from Organization) Possibly over 1e23 FLOP  \
# 3                                          Industry                     NaN
# 8                                          Industry                 checked
# 11                                       Government                 checked
# 12                                         Industry                 checked
# 14                                         Industry                     NaN
# ..                                              ...                     ...
# 564                                        Industry                     NaN
# 573                               Academia,Academia                     NaN
# 574                                        Industry                     NaN
# 589                                        Academia                     NaN
# 663                      Academia,Academia,Academia                     NaN
#
#     Training compute cost (2023 USD)    Training dataset size Sparsity  \
# 3                                NaN          Nemotron-4 340B      NaN
# 8                                NaN              Llama 3-70B      NaN
# 11                      $10340911.71              Falcon-180B      NaN
# 12                               NaN                   Grok-1      NaN
# 14                               NaN                     DBRX     DBRX
# ..                               ...                      ...      ...
# 564                              NaN  Big-Little Net (speech)      NaN
# 573                              NaN                  ULM-FiT      NaN
# 574                              NaN           Big-Little Net      NaN
# 589                              NaN                   DNCON2      NaN
# 663                              NaN                  SPIDER2      NaN
#
#     Model open/closed Publication date (float)  top_10_at_release
# 3                Open              2024.452259               True
# 8                Open              2024.296544               True
# 11               Open              2023.680356               True
# 12               Open              2023.841547               True
# 14               Open              2024.237852               True
# ..                ...                      ...                ...
# 564              Open              2018.524641               True
# 573              Open              2018.046544               True
# 574              Open              2018.524641               True
# 589              Open              2018.333333               True
# 663              Open              2016.823924               True
#
# [81 rows x 64 columns]

# %%
access_df[(access_df['top_10_at_release'] == True) & (access_df['Model open/closed'] == 'Closed')]
# Out:
#                       System                                       Domain  \
# 0           Gemini 1.0 Ultra                   Multimodal,Language,Vision
# 1                      GPT-4  Multimodal,Language,Vision,Image generation
# 2              Mistral Large                                     Language
# 4     MegaScale (Production)                                     Language
# 5               Inflection-2                                     Language
# ..                       ...                                          ...
# 628                   VD-RHN                                     Language
# 631  Search-Proven Best LSTM                                     Language
# 636          LSTM-Char-Large                                     Language
# 645                      LBL                                     Language
# 702       Credibilty Network                                       Vision
#
#                                                   Task Publication date  \
# 0    Language modelling,Visual question answering,C...       2023-12-06
# 1                                   Language modelling       2023-03-15
# 2                                                 Chat       2024-02-26
# 4                        Language modelling/generation       2024-02-23
# 5    Language modelling,Language modelling/generati...       2023-11-22
# ..                                                 ...              ...
# 628                                                NaN       2016-07-12
# 631                                                NaN       2015-07-06
# 636                                                NaN       2015-08-26
# 645                                                NaN       2012-06-27
# 702         Character recognition,Image classification       1999-07-01
#
#                                    Accessibility notes  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 4    Code for MegaScale (also called veScale) train...
# 5                                       via Pi, no API
# ..                                                 ...
# 628  MIT for code: https://github.com/jzilly/Recurr...
# 631                                                NaN
# 636  code, MIT license: https://github.com/yoonkim/...
# 645                                                NaN
# 702                                                NaN
#
#         Model accessibility Dataset accessibility Code accessibility  \
# 0    Hosted access (no API)                   NaN         Unreleased
# 1                API access                   NaN         Unreleased
# 2                API access                   NaN         Unreleased
# 4                Unreleased                   NaN         Unreleased
# 5    Hosted access (no API)                   NaN         Unreleased
# ..                      ...                   ...                ...
# 628              Unreleased                   NaN        Open source
# 631              Unreleased                   NaN         Unreleased
# 636              Unreleased                   NaN        Open source
# 645              Unreleased                   NaN         Unreleased
# 702              Unreleased                   NaN         Unreleased
#
#                                                   Link  \
# 0    https://storage.googleapis.com/deepmind-media/...
# 1                     https://arxiv.org/abs/2303.08774
# 2               https://mistral.ai/news/mistral-large/
# 4                     https://arxiv.org/abs/2402.15627
# 5                   https://inflection.ai/inflection-2
# ..                                                 ...
# 628                   https://arxiv.org/abs/1607.03474
# 631  https://proceedings.mlr.press/v37/jozefowicz15...
# 636                   https://arxiv.org/abs/1508.06615
# 645                    https://arxiv.org/abs/1206.6426
# 702  https://proceedings.neurips.cc/paper_files/pap...
#
#                                           Organization  ...  \
# 0                                      Google DeepMind  ...
# 1                                               OpenAI  ...
# 2                                           Mistral AI  ...
# 4                          ByteDance,Peking University  ...
# 5                                        Inflection AI  ...
# ..                                                 ...  ...
# 628                                   ETH Zurich,IDSIA  ...
# 631          Google,New York University (NYU),Facebook  ...
# 636       Harvard University,New York University (NYU)  ...
# 645                    University College London (UCL)  ...
# 702  University College London (UCL),University of ...  ...
#
#      Training compute upper bound Training chip-hours  \
# 0                             NaN         132000000.0
# 1                             NaN          57000000.0
# 2                             NaN                 NaN
# 4                             NaN                 NaN
# 5                             NaN                 NaN
# ..                            ...                 ...
# 628                           NaN                 NaN
# 631                           NaN                 NaN
# 636                           NaN                 NaN
# 645                           NaN                 NaN
# 702                           NaN                 NaN
#
#     Organization categorization (from Organization) Possibly over 1e23 FLOP  \
# 0                                          Industry                     NaN
# 1                                          Industry                     NaN
# 2                                          Industry                     NaN
# 4                                 Industry,Academia                     NaN
# 5                                          Industry                     NaN
# ..                                              ...                     ...
# 628                               Academia,Academia                     NaN
# 631                      Industry,Academia,Industry                     NaN
# 636                               Academia,Academia                     NaN
# 645                                        Academia                     NaN
# 702                               Academia,Academia                     NaN
#
#     Training compute cost (2023 USD)    Training dataset size Sparsity  \
# 0                       $29827341.92         Gemini 1.0 Ultra      NaN
# 1                       $40586592.58                    GPT-4    GPT-4
# 2                                NaN            Mistral Large      NaN
# 4                                NaN   MegaScale (Production)      NaN
# 5                       $12961959.00             Inflection-2      NaN
# ..                               ...                      ...      ...
# 628                              NaN                   VD-RHN      NaN
# 631                              NaN  Search-Proven Best LSTM      NaN
# 636                              NaN          LSTM-Char-Large      NaN
# 645                              NaN                      LBL      NaN
# 702                              NaN       Credibilty Network      NaN
#
#     Model open/closed Publication date (float)  top_10_at_release
# 0              Closed              2023.930356               True
# 1              Closed              2023.204997               True
# 2              Closed              2024.151781               True
# 4              Closed              2024.143567               True
# 5              Closed              2023.890829               True
# ..                ...                      ...                ...
# 628            Closed              2016.530117               True
# 631            Closed              2015.513690               True
# 636            Closed              2015.651781               True
# 645            Closed              2012.487852               True
# 702            Closed              1999.500000               True
#
# [84 rows x 64 columns]

# %% [markdown]
# # Regression

# %%
# tentative
start_year = 2015

frontier_df = access_df[(access_df[f'top_{n}_at_release'] == True) & (access_df['Publication date (float)'] >= start_year)]


# frontier_df = access_df.loc[access_df['System'].isin(selected_systems)]

# %%
reg_results = fit_ols_regression(
    frontier_df,
    ['Publication date (float)'],
    'Training compute (FLOP)',
    logy=True
)
reg_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.818
# Model:                            OLS   Adj. R-squared:                  0.817
# Method:                 Least Squares   F-statistic:                     711.5
# Date:                Tue, 02 Jul 2024   Prob (F-statistic):           2.17e-60
# Time:                        09:19:50   Log-Likelihood:                -244.44
# No. Observations:                 160   AIC:                             492.9
# Df Residuals:                     158   BIC:                             499.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2056.9430     77.926    -26.396      0.000   -2210.854   -1903.032
# x1             1.0287      0.039     26.674      0.000       0.953       1.105
# ==============================================================================
# Omnibus:                       12.661   Durbin-Watson:                   1.048
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               32.836
# Skew:                          -0.150   Prob(JB):                     7.41e-08
# Kurtosis:                       5.199   Cond. No.                     1.78e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.78e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
open_reg_results = fit_ols_regression(
    frontier_df[frontier_df['Model open/closed'] == 'Open'],
    ['Publication date (float)'],
    'Training compute (FLOP)',
    logy=True
)
open_reg_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.785
# Model:                            OLS   Adj. R-squared:                  0.782
# Method:                 Least Squares   F-statistic:                     287.9
# Date:                Tue, 02 Jul 2024   Prob (F-statistic):           4.56e-28
# Time:                        09:19:50   Log-Likelihood:                -116.70
# No. Observations:                  81   AIC:                             237.4
# Df Residuals:                      79   BIC:                             242.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1886.2489    112.455    -16.773      0.000   -2110.085   -1662.413
# x1             0.9441      0.056     16.968      0.000       0.833       1.055
# ==============================================================================
# Omnibus:                       35.915   Durbin-Watson:                   0.583
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              133.174
# Skew:                          -1.298   Prob(JB):                     1.21e-29
# Kurtosis:                       8.720   Cond. No.                     1.98e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.98e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
closed_reg_results = fit_ols_regression(
    frontier_df[frontier_df['Model open/closed'] == 'Closed'],
    ['Publication date (float)'],
    'Training compute (FLOP)',
    logy=True
)
closed_reg_results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.858
# Method:                 Least Squares   F-statistic:                     473.6
# Date:                Tue, 02 Jul 2024   Prob (F-statistic):           1.25e-34
# Time:                        09:19:50   Log-Likelihood:                -120.06
# No. Observations:                  79   AIC:                             244.1
# Df Residuals:                      77   BIC:                             248.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2270.6194    105.320    -21.559      0.000   -2480.338   -2060.901
# x1             1.1346      0.052     21.762      0.000       1.031       1.238
# ==============================================================================
# Omnibus:                       11.908   Durbin-Watson:                   1.041
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               14.905
# Skew:                           0.691   Prob(JB):                     0.000580
# Kurtosis:                       4.618   Cond. No.                     1.69e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.69e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
print('All:')
print_growth_rates(reg_results)
print('Open:')
print_growth_rates(open_reg_results)
print('Closed:')
print_growth_rates(closed_reg_results)
# Out:
# All:
# Adj. R^2=0.82
# 1.03 OOMs/year (95% CI: 0.95, 1.10)
# 10.7x/year (95% CI: 9.0x, 12.7x)
# doubling time of 4 months (95% CI: 3, 4)
# Open:
# Adj. R^2=0.78
# 0.94 OOMs/year (95% CI: 0.83, 1.05)
# 8.8x/year (95% CI: 6.8x, 11.3x)
# doubling time of 4 months (95% CI: 3, 4)
# Closed:
# Adj. R^2=0.86
# 1.13 OOMs/year (95% CI: 1.03, 1.24)
# 13.6x/year (95% CI: 10.7x, 17.3x)
# doubling time of 3 months (95% CI: 3, 4)

# %% [markdown]
# ## Predictions

# %%
pred_start_year = start_year
pred_end_year = 2025
pred_start_date = f'{pred_start_year}-01-01'
pred_end_date = f'{pred_end_year}-01-01'
num_preds = (pred_end_year - pred_start_year) * 12 + 1

pred_years = pd.DataFrame({'Publication date (float)': np.linspace(pred_start_year, pred_end_year, num_preds)})
pred_years
# Out:
#      Publication date (float)
# 0                 2015.000000
# 1                 2015.083333
# 2                 2015.166667
# 3                 2015.250000
# 4                 2015.333333
# ..                        ...
# 116               2024.666667
# 117               2024.750000
# 118               2024.833333
# 119               2024.916667
# 120               2025.000000
#
# [121 rows x 1 columns]

# %%
predicted_open_df = get_predictions(open_reg_results, pred_years, ['Publication date (float)'])
predicted_open_df['Publication date'] = predicted_open_df['Publication date (float)'].apply(float_year_to_datetime)
predicted_open_df
# Out:
#           mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0    16.140708  0.358602      15.426929      16.854487     13.960519
# 1    16.219384  0.354213      15.514341      16.924427     14.042039
# 2    16.298060  0.349831      15.601740      16.994381     14.123524
# 3    16.376736  0.345455      15.689125      17.064347     14.204974
# 4    16.455412  0.341086      15.776497      17.134328     14.286387
# ..         ...       ...            ...            ...           ...
# 116  25.267143  0.229138      24.811055      25.723231     23.157223
# 117  25.345819  0.233160      24.881725      25.809913     23.234154
# 118  25.424495  0.237205      24.952351      25.896639     23.311047
# 119  25.503171  0.241271      25.022934      25.983408     23.387900
# 120  25.581848  0.245357      25.093477      26.070218     23.464715
#
#      obs_ci_upper  Publication date (float) Publication date
# 0       18.320897               2015.000000       2015-01-01
# 1       18.396729               2015.083333       2015-01-31
# 2       18.472596               2015.166667       2015-03-02
# 3       18.548499               2015.250000       2015-04-02
# 4       18.624438               2015.333333       2015-05-02
# ..            ...                       ...              ...
# 116     27.377063               2024.666667       2024-09-01
# 117     27.457484               2024.750000       2024-10-01
# 118     27.537944               2024.833333       2024-10-31
# 119     27.618443               2024.916667       2024-12-01
# 120     27.698980               2025.000000       2025-01-01
#
# [121 rows x 8 columns]

# %%
predicted_open_df.set_index('Publication date', inplace=True)

# %%
predicted_closed_df = get_predictions(closed_reg_results, pred_years, ['Publication date (float)'])
predicted_closed_df['Publication date'] = predicted_closed_df['Publication date (float)'].apply(float_year_to_datetime)
predicted_closed_df
# Out:
#           mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0    15.581533  0.295273      14.993569      16.169498     13.274493
# 1    15.676083  0.291350      15.095930      16.256235     13.371021
# 2    15.770632  0.287440      15.198266      16.342997     13.467518
# 3    15.865181  0.283541      15.300578      16.429784     13.563984
# 4    15.959730  0.279656      15.402863      16.516597     13.660419
# ..         ...       ...            ...            ...           ...
# 116  26.549247  0.268395      26.014803      27.083690     24.255263
# 117  26.643796  0.272239      26.101699      27.185892     24.348017
# 118  26.738345  0.276097      26.188566      27.288124     24.440740
# 119  26.832894  0.279969      26.275404      27.390384     24.533432
# 120  26.927444  0.283855      26.362215      27.492672     24.626093
#
#      obs_ci_upper  Publication date (float) Publication date
# 0       17.888573               2015.000000       2015-01-01
# 1       17.981144               2015.083333       2015-01-31
# 2       18.073746               2015.166667       2015-03-02
# 3       18.166378               2015.250000       2015-04-02
# 4       18.259042               2015.333333       2015-05-02
# ..            ...                       ...              ...
# 116     28.843230               2024.666667       2024-09-01
# 117     28.939575               2024.750000       2024-10-01
# 118     29.035950               2024.833333       2024-10-31
# 119     29.132357               2024.916667       2024-12-01
# 120     29.228794               2025.000000       2025-01-01
#
# [121 rows x 8 columns]

# %%
predicted_closed_df.set_index('Publication date', inplace=True)

# %% [markdown]
# ## Differences between trends

# %%
NUM_SAMPLES = 1000

# %%
open_reg_results.conf_int()
# Out:
# array([[-2.11008476e+03, -1.66241313e+03],
#        [ 8.33364785e-01,  1.05486316e+00]])

# %%
median_date = datetime_to_float_year(pd.to_datetime(frontier_df['Publication date'])).median()
median_date
# Out:
# 2020.5410686192727

# %%
compute_refs = {}
for key, value in {'open': open_reg_results, 'closed': closed_reg_results}.items():
    X = np.array([median_date, 1])  # dummy 1 value makes this work
    X = sm.add_constant(X)
    ref_preds = value.get_prediction(X).summary_frame()
    compute_ref_low = ref_preds['mean_ci_lower'][0]
    compute_ref_high = ref_preds['mean_ci_upper'][0]
    compute_refs[key] = compute_ref_low, compute_ref_high
compute_refs
# Out:
# {'open': (21.134858382459946, 21.609357913464684),
#  'closed': (21.613639784686946, 22.123120298214864)}

# %%
# Open
open_ci = open_reg_results.conf_int()
open_slope = lognorm_from_90_ci(
    10**open_ci[1][0],
    10**open_ci[1][1],
    NUM_SAMPLES,
)
# Closed
closed_ci = closed_reg_results.conf_int()
closed_slope = lognorm_from_90_ci(
    10**closed_ci[1][0],
    10**closed_ci[1][1],
    NUM_SAMPLES,
)

# %%
print_median_and_ci(open_slope)
print_median_and_ci(closed_slope)
# Out:
# Median: 8.8 [90% CI: 6.7, 11]
# Median: 14 [90% CI: 11, 17]

# %%
# Calculate when the closed compute trend was equal to the open compute trend today
current_date = '2024-05-01'
current_open_compute_df = predicted_open_df.loc[current_date]
current_open_compute = lognorm_from_90_ci(
    10**current_open_compute_df['mean_ci_lower'],
    10**current_open_compute_df['mean_ci_upper'],
    NUM_SAMPLES,
)
print_median_and_ci(current_open_compute)
# Out:
# Median: 9e+24 [90% CI: 3.2e+24, 2.3e+25]

# %%
# Same for closed
current_closed_compute_df = predicted_closed_df.loc[current_date]
current_closed_compute = lognorm_from_90_ci(
    10**current_closed_compute_df['mean_ci_lower'],
    10**current_closed_compute_df['mean_ci_upper'],
    NUM_SAMPLES,
)
print_median_and_ci(current_closed_compute)
# Out:
# Median: 1.5e+26 [90% CI: 4.8e+25, 4.9e+26]

# %%
compute_gap = np.log10(current_closed_compute) - np.log10(current_open_compute)
print(
    f'Open access models are {np.median(compute_gap):.1f} OOMs ' + 
    f'[{np.percentile(compute_gap, 2.5):.1f}; {np.percentile(compute_gap, 97.5):.1f}] ' + 
    'behind closed access models'
)
# Out:
# Open access models are 1.2 OOMs [0.5; 2.0] behind closed access models

# %%
# Calculate when the closed compute trend was equal to the open compute trend today

np.random.seed(42)
open_frontier_df =  frontier_df[frontier_df['Model open/closed'] == 'Open']
closed_frontier_df = frontier_df[frontier_df['Model open/closed'] == 'Closed']

n_bootstrap = 1000
open_filtered_access_bootstrap_indices = [np.arange(0, len(open_frontier_df))] + \
                                          [np.random.choice(np.arange(0, len(open_frontier_df)), size=len(open_frontier_df), replace=True) for _ in range(n_bootstrap)]
closed_filtered_access_bootstrap_indices = [np.arange(0, len(closed_frontier_df))] + \
                                            [np.random.choice(np.arange(0, len(closed_frontier_df)), size=len(closed_frontier_df), replace=True) for _ in range(n_bootstrap)]

current_date_float = 2024.35
results_date_float = []

for i in range(n_bootstrap+1):
    open_reg_results_current = fit_ols_regression(
        open_frontier_df.iloc[open_filtered_access_bootstrap_indices[i]],
        ['Publication date (float)'],
        'Training compute (FLOP)',
        logy=True
    )

    closed_reg_results_current = fit_ols_regression(
        closed_frontier_df.iloc[closed_filtered_access_bootstrap_indices[i]],
        ['Publication date (float)'],
        'Training compute (FLOP)',
        logy=True
    )

    alpha_o, beta_o = open_reg_results_current.params
    alpha_c, beta_c = closed_reg_results_current.params

    current_log10_compute = alpha_o + beta_o*current_date_float
    results_date_float.append((current_log10_compute - alpha_c)/beta_c)

# %%
print("Point estimate: %.4f" % (results_date_float[0]))
print("Standard error: %.4f years" % (np.std(results_date_float[1:])))
# Out:
# Point estimate: 2023.2731
# Standard error: 0.1976 years

# %%
current_date = 2024.25
current_open_compute = open_reg_results.params[1] * current_date + open_reg_results.params[0]
current_open_compute
# Out:
# 24.873762088228204

# %%
closed_compute_match_date = (current_open_compute - closed_reg_results.params[0]) / closed_reg_results.params[1]
closed_compute_match_date
# Out:
# 2023.1899367655062

# %%
open_time_lag = current_date - closed_compute_match_date
print(f'Open access models are {open_time_lag:.1f} years behind closed access models')
# Out:
# Open access models are 1.1 years behind closed access models

# %% [markdown]
# # Model count plots

# %%
access_df['Year'] = pd.to_datetime(access_df['Publication date']).dt.year

# get counts of all models by year and model accessibility
access_counts = access_df.loc[access_df['Year'] >= 2015].groupby(['Year', 'Model accessibility']).size().reset_index(name='Count')

# add up cumulative counts by accessibility status for each year 
access_counts['Cumulative for status'] = access_counts.groupby('Model accessibility')['Count'].cumsum()

# cumulative area chart
fig = px.area(access_counts, x='Year', y='Cumulative for status', color='Model accessibility', line_group='Model accessibility',
              labels={'Cumulative for status': 'Cumulative Count', 'Year': 'Year'},
              title='Model count by accessibility over time')

fig.update_layout(
    autosize=False,
    width=900,
    height=600,
    title_x=0.2,
)

save_plot(fig, results_dir, f'cumulative_model_count_by_accessibility')

fig.show()
# Out:
# /var/folders/06/5htx0qw164j099bw2q7jk4gm0000gn/T/ipykernel_72057/26653989.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ### Cumulative proportion plots

# %%
def normalize_counts(access_counts):
    # input -  model counts, grouped by accessibility and by year
    
    # df with total models per year, and cumulative totals
    total_counts = access_counts.groupby('Year')['Count'].sum().reset_index(name='Yearly Total')
    total_counts['Cumulative Total'] = total_counts['Yearly Total'].cumsum()
    
    # pivot the access counts table to get counts for every status and every year
    access_counts_wide = access_counts.pivot(index='Year', columns='Model accessibility', values='Cumulative for status')
    all_years = pd.Series(range(access_counts_wide.index.min(), access_counts_wide.index.max() + 1))

    # fill in the years where there are no models with a particular status
    access_counts_wide_filled = access_counts_wide.reindex(all_years).ffill().fillna(0)
    access_counts_wide_filled = access_counts_wide_filled.reset_index(names=["Year"])
    
    # unpivot
    access_counts_filled = (access_counts_wide_filled.melt(id_vars='Year', 
                                     var_name='Model accessibility', 
                                     value_name='Cumulative for status')
                               .reset_index(drop=True))
    
    # join with total counts df to get the cumulative totals
    normalized_counts = pd.merge(access_counts_filled, total_counts, on='Year')
    
    # divide annual counts by cumulative counts to find cumulative proportions by year
    normalized_counts['proportion'] = normalized_counts['Cumulative for status'] / normalized_counts['Cumulative Total']
    
    # sort using custom order
    custom_order = ['Unreleased', 'Hosted access (no API)', 'API access', 'Open access (non-commercial)', 'Open access (restricted use)', 'Open source']
    normalized_counts['Category_sorted'] = pd.Categorical(normalized_counts['Model accessibility'], categories=custom_order, ordered=True)
    normalized_counts = normalized_counts.sort_values('Category_sorted')
    
    return normalized_counts

# %%
normalized_counts = normalize_counts(access_counts)

fig = px.area(normalized_counts, x='Year', y='proportion', color='Model accessibility', line_group='Model accessibility',
              labels={'proportion': 'Proportion', 'Year': 'Year'},
              title='Cumulative proportion of models by accessibility over time')

fig.update_yaxes(range=[0, 1])
fig.update_layout(
    autosize=False,
    width=900,
    height=600,
    title_x=0.2,
)

# save_plot(fig, results_dir, f'proportion_by_accessibility')
fig.show()

# %%
# repeat the above for frontier models

frontier_df['Year'] = pd.to_datetime(frontier_df['Publication date']).dt.year

# get counts of all models by year and model accessibility
frontier_access_counts = frontier_df.loc[access_df['Year'] >= 2015].groupby(['Year', 'Model accessibility']).size().reset_index(name='Count')

# add up cumulative counts by accessibility status for each year 
frontier_access_counts['Cumulative for status'] = frontier_access_counts.groupby('Model accessibility')['Count'].cumsum()


normalized_counts = normalize_counts(frontier_access_counts)

fig = px.area(normalized_counts, x='Year', y='proportion', color='Model accessibility', line_group='Model accessibility',
              labels={'proportion': 'Proportion', 'Year': 'Year'},
              title='Cumulative proportion of frontier models by accessibility over time')

fig.update_yaxes(range=[0, 1])
fig.update_layout(
    autosize=False,
    width=900,
    height=600,
    title_x=0.2,
)

# save_plot(fig, results_dir, f'proportion_by_accessibility')
fig.show()
# Out:
# /var/folders/06/5htx0qw164j099bw2q7jk4gm0000gn/T/ipykernel_72057/4194927785.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
open_closed_df = access_df.loc[access_df['Year'] >= 2015].groupby(['Year', 'Model open/closed']).size().reset_index(name='Count')
open_closed_df['Cumulative for status'] = open_closed_df.groupby('Model open/closed')['Count'].cumsum()

fig = px.area(open_closed_df, x='Year', y='Cumulative for status', color='Model open/closed', line_group='Model open/closed',
              labels={'Cumulative for status': 'Cumulative Count', 'Year': 'Year'},
              title='Model count by open/closed over time')
fig.update_layout(
    autosize=False,
    width=800,
    height=600,
    title_x=0.2,
)

save_plot(fig, results_dir, f'cumulative_model_count_by_open_closed')
fig.show()

# %%
total_counts = open_closed_df.groupby('Year')['Count'].sum().reset_index(name='Yearly Total')
total_counts['Cumulative Total'] = total_counts['Yearly Total'].cumsum()

open_counts = pd.merge(open_closed_df, total_counts, on='Year')
open_counts.head(5)
# Out:
#    Year Model open/closed  Count  Cumulative for status  Yearly Total  \
# 0  2015            Closed      4                      4             4
# 1  2016            Closed      7                     11             9
# 2  2016              Open      2                      2             9
# 3  2017            Closed     11                     22            12
# 4  2017              Open      1                      3            12
#
#    Cumulative Total
# 0                 4
# 1                13
# 2                13
# 3                25
# 4                25

# %%
total_counts
# Out:
#    Year  Yearly Total  Cumulative Total
# 0  2015             4                 4
# 1  2016             9                13
# 2  2017            12                25
# 3  2018            36                61
# 4  2019            55               116
# 5  2020            55               171
# 6  2021            93               264
# 7  2022            79               343
# 8  2023           142               485
# 9  2024            44               529

# %%
normalized_open = open_counts.copy()
# double check this code, am I missing a step?
normalized_open['proportion'] = open_counts['Cumulative for status'] / open_counts['Cumulative Total']
normalized_open.head(10)
# Out:
#    Year Model open/closed  Count  Cumulative for status  Yearly Total  \
# 0  2015            Closed      4                      4             4
# 1  2016            Closed      7                     11             9
# 2  2016              Open      2                      2             9
# 3  2017            Closed     11                     22            12
# 4  2017              Open      1                      3            12
# 5  2018            Closed     24                     46            36
# 6  2018              Open     12                     15            36
# 7  2019            Closed     31                     77            55
# 8  2019              Open     24                     39            55
# 9  2020            Closed     27                    104            55
#
#    Cumulative Total  proportion
# 0                 4    1.000000
# 1                13    0.846154
# 2                13    0.153846
# 3                25    0.880000
# 4                25    0.120000
# 5                61    0.754098
# 6                61    0.245902
# 7               116    0.663793
# 8               116    0.336207
# 9               171    0.608187

# %%
fig = px.area(normalized_open, x='Year', y='proportion', color='Model open/closed', line_group='Model open/closed',
              labels={'proportion': 'Proportion', 'Year': 'Year'},
              title='Cumulative proportion of models open/closed')

fig.update_yaxes(range=[0, 1])
fig.update_layout(
    autosize=False,
    width=900,
    height=600,
    title_x=0.2,
)
# Show the figure
fig.show()

# %% [markdown]
# # Regression Plots

# %%
# filter out systems before start of analysis (2015)
access_df_recent = frontier_df[frontier_df['Publication date'] > pred_start_date]

fig = px.scatter(
    access_df_recent,
    x='Publication date',
    y='Training compute (FLOP)',
    color='Model accessibility',
    hover_data=['System'],
    log_y=True,
    title='Training compute by model accessibility'
)

# update size
fig.update_layout(
    autosize=False,
    width=900,
    height=600,
    title_x=0.2,
)

save_plot(fig, results_dir, f'training_compute_by_model_accessibility {start_year}')

fig.show()

# %%
fig = px.scatter(
    # access_df,
    # access_df.loc[access_df_recent['System'].isin(selected_systems)],
    access_df_recent,
    x='Publication date',
    y='Training compute (FLOP)',
    color='Model open/closed',
    hover_data=['System'],
    log_y=True,
    title='Training compute by model open/closed'
)
# update size
fig.update_layout(
    autosize=False,
    width=900,
    height=600,
    title_x=0.25,
)

save_plot(fig, results_dir, f'training_compute_by_open_closed {start_year}')

fig.show()

# %%
fig = px.scatter(
    # access_df,
    # access_df.loc[access_df['System'].isin(selected_systems)],
    access_df_recent,
    x='Publication date (float)',
    y='Training compute (FLOP)',
    color='Model open/closed',
    hover_data=['System'],
    log_y=True,
)

# Marker color
# fig.update_traces(
#     marker=dict(
#         color='rgb(0,100,200)',
#     ),
#     selector=dict(mode='markers'),
# )

# Shade in CI
fig.add_scatter(
    x=predicted_open_df['Publication date (float)'],
    y=10**predicted_open_df['mean_ci_lower'],
    mode='lines',
    line=dict(width=0),
    showlegend=False,
)
fig.add_scatter(
    x=predicted_open_df['Publication date (float)'],
    y=10**predicted_open_df['mean_ci_upper'],
    mode='lines',
    fill='tonexty',
    fillcolor='rgba(230,100,0,0.2)',
    line=dict(width=0),
    name='95% CI of mean',
)
fig.add_scatter(
    x=predicted_open_df['Publication date (float)'],
    y=10**predicted_open_df['mean'],
    mode='lines',
    line=dict(color='rgb(230,100,0)'),
    name=f'Regression mean (growth rate: {10**open_reg_results.params[1]:.1f}x per year)',
)

fig.add_scatter(
    x=predicted_closed_df['Publication date (float)'],
    y=10**predicted_closed_df['mean_ci_lower'],
    mode='lines',
    line=dict(width=0),
    showlegend=False,
)
fig.add_scatter(
    x=predicted_closed_df['Publication date (float)'],
    y=10**predicted_closed_df['mean_ci_upper'],
    mode='lines',
    fill='tonexty',
    fillcolor='rgba(0,100,200,0.2)',
    line=dict(width=0),
    name='95% CI of mean',
)
fig.add_scatter(
    x=predicted_closed_df['Publication date (float)'],
    y=10**predicted_closed_df['mean'],
    mode='lines',
    line=dict(color='rgb(0,100,200)'),
    name=f'Regression mean (growth rate: {10**closed_reg_results.params[1]:.1f}x per year)',
)

fig.update_traces(textposition='top center')

# legend on top
fig.update_layout(legend=dict(
    orientation='h',
    yanchor='top',
    y=-0.15,
    xanchor='center',
    x=0.5,
))

# axis labels
fig.update_xaxes(title_text='Publication date')

# title

# update size
fig.update_layout(
    autosize=False,
    width=800,
    height=600,
    # title_x=0.2,
)

# font size
fig.update_layout(
    font=dict(
        size=14,
    )
)

# axis limits
fig.update_xaxes(range=[pred_start_date, pred_end_date])

# margins
fig.update_layout(margin=dict(l=10, r=10, t=40, b=10))

save_plot(fig, results_dir, f'open_closed_regression {start_year}')

fig.show()
